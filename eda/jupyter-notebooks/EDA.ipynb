# %%
import pandas as pd

# %%
file_path = '/Users/MHollowed/Desktop/final_project/HousingPricePredictor/data/csvs/EXTR_RPSale.csv'
df = pd.read_csv(file_path)
# Out:
# /Users/MHollowed/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_ = df[:100]

# %%
df_.head().T
# Out:
#                                                                     0  \
# ExciseTaxNbr                                                  2671216
# Major                                                           98400
# Minor                                                             380
# DocumentDate                                               04/02/2014
# SalePrice                                                           0
# RecordingNbr                                           20140602000186
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          DWORSHAK LYNDEE MARIE                         ...
# BuyerName           DWORSHAK MICHAEL J                            ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                     15
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         11
# PropertyClass                                                       8
# SaleWarning                                                  18 31 38
#
#                                                                     1  \
# ExciseTaxNbr                                                  2201052
# Major                                                          889980
# Minor                                                             280
# DocumentDate                                               03/03/2006
# SalePrice                                                           0
# RecordingNbr                                           20060420001615
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          MOORE JEFFERY A                               ...
# BuyerName           HAMPTON JAMES W+VICTORIA A                    ...
# PropertyType                                                        3
# PrincipalUse                                                        2
# SaleInstrument                                                     15
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         14
# PropertyClass                                                       3
# SaleWarning                                               18 31 51 52
#
#                                                                     2  \
# ExciseTaxNbr                                                  2548641
# Major                                                          330395
# Minor                                                            1610
# DocumentDate                                               06/07/2012
# SalePrice                                                      335000
# RecordingNbr                                           20120615000867
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          THORSON CONNIE+TODD                           ...
# BuyerName           YATTEAU PAUL A+TAMARA J                       ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                      3
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                          1
# PropertyClass                                                       8
# SaleWarning
#
#                                                                     3  \
# ExciseTaxNbr                                                  1598443
# Major                                                          675260
# Minor                                                             940
# DocumentDate                                               03/06/1998
# SalePrice                                                      209950
# RecordingNbr                                           199803122092
# Volume                                                            165
# Page                                                              041
# PlatNbr                                                        675260
# PlatType                                                            P
# PlatLot                                                94
# PlatBlock
# SellerName          HART JOHN W II+ANDREA T                       ...
# BuyerName           HANSON KEVIN P+JENNA M                        ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                      3
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                          1
# PropertyClass                                                       8
# SaleWarning
#
#                                                                     4
# ExciseTaxNbr                                                  2339550
# Major                                                          795508
# Minor                                                             170
# DocumentDate                                               03/28/2008
# SalePrice                                                           0
# RecordingNbr                                           20080331002272
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          SCHWEIGER MICHAEL M                           ...
# BuyerName           SCHWEIGER MICHAEL W                           ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                     15
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         18
# PropertyClass                                                       8
# SaleWarning                                                  18 31 51

# %%
mask = df['hollowed' in df['SellerName'].str.lower()]
df[mask].head().T
# Out:
# ----------------------------------------------------------------------
# KeyError                             Traceback (most recent call last)
# <ipython-input-8-7248201dab9e> in <module>()
# ----> 1 mask = df['hollowed' in df['SellerName'].str.lower()]
#       2 df[mask].head().T
#
# /Users/MHollowed/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/MHollowed/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/MHollowed/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/MHollowed/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/MHollowed/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: False
